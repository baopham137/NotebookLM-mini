# %%
import pandas as pd
from IPython.display import display, HTML

# %%
df = pd.read_csv("ragbench_evaluation_final.csv", encoding="utf-8")

html = df.head(2).to_html(escape=True)

css = """
<style>
table {
    width: 100%;
    border-collapse: collapse;
}
th, td {
    border: 1px solid #ddd;
    padding: 8px;
    vertical-align: top;
    max-width: 400px;
    white-space: pre-wrap;
    word-break: break-word;
}
</style>
"""

display(HTML(css + html))
# Out:
# <style>
# table {
#     width: 100%;
#     border-collapse: collapse;
# }
# th, td {
#     border: 1px solid #ddd;
#     padding: 8px;
#     vertical-align: top;
#     max-width: 400px;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>question</th>
#       <th>documents</th>
#       <th>ground_truth</th>
#       <th>response_AI</th>
#       <th>top_chunks</th>
#       <th>faithfulness</th>
#       <th>answer_relevancy</th>
#       <th>context_precision</th>
#       <th>context_recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5ab67ce2554299710c8d1ead</td>
#       <td>Which has more species in Asia, Disporum or Boltonia?</td>
# ...

# %%
print(df['faithfulness'].describe())
print(df['answer_relevancy'].describe())
# Out:
# count    63.000000
# mean      0.812562
# std       0.223209
# min       0.000000
# 25%       0.666700
# 50%       0.875000
# 75%       1.000000
# max       1.000000
# Name: faithfulness, dtype: float64
# count    63.000000
# mean      0.693187
# std       0.284797
# min       0.000000
# 25%       0.691800
# 50%       0.762200
# 75%       0.886100
# max       0.952500
# Name: answer_relevancy, dtype: float64

# %%
print(df['context_precision'].describe())
print(df['context_recall'].describe())
# Out:
# count    62.000000
# mean      0.758065
# std       0.402268
# min       0.000000
# 25%       0.500000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: context_precision, dtype: float64
# count    63.000000
# mean      0.944444
# std       0.221998
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: context_recall, dtype: float64

# %%
ds = pd.read_json("rag_results_hotpotqa.jsonl", encoding="utf-8", lines=True)

html_ds = ds.head(2).to_html(escape=True)

css = """
<style>
table {
    width: 100%;
    border-collapse: collapse;
}
th, td {
    border: 1px solid #ddd;
    padding: 8px;
    vertical-align: top;
    max-width: 400px;
    white-space: pre-wrap;
    word-break: break-word;
}
</style>
"""

display(HTML(css + html_ds))
# Out:
# <style>
# table {
#     width: 100%;
#     border-collapse: collapse;
# }
# th, td {
#     border: 1px solid #ddd;
#     padding: 8px;
#     vertical-align: top;
#     max-width: 400px;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>question</th>
#       <th>documents</th>
#       <th>ground_truth</th>
#       <th>response_AI</th>
#       <th>top_chunks</th>
#       <th>latency_retrieve_s</th>
#       <th>latency_generate_s</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5ab67ce2554299710c8d1ead</td>
#       <td>Which has more species in Asia, Disporum or Boltonia?</td>
# ...

# %%
dr = pd.read_json("hotpotqa_top500.jsonl", encoding="utf-8", lines=True)

html_dr = dr.head(2).to_html(escape=True)

css = """
<style>
table {
    width: 100%;
    border-collapse: collapse;
}
th, td {
    border: 1px solid #ddd;
    padding: 8px;
    vertical-align: top;
    max-width: 400px;
    white-space: pre-wrap;
    word-break: break-word;
}
</style>
"""

display(HTML(css + html_dr))
# Out:
# <style>
# table {
#     width: 100%;
#     border-collapse: collapse;
# }
# th, td {
#     border: 1px solid #ddd;
#     padding: 8px;
#     vertical-align: top;
#     max-width: 400px;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>question</th>
#       <th>documents</th>
#       <th>ground_truth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5ab67ce2554299710c8d1ead</td>
#       <td>Which has more species in Asia, Disporum or Boltonia?</td>
#       <td>[Boltonia is a genus of plants in the sunflower family native primarily to North America with one species in eastern Asia., Disporum (commonly known as fairy bells) is a genus of about 20 species of perennial flowering plants, found in Asia from northern India to Japan, south to Indonesia and north into the Russian Far East.]</td>
# ...
